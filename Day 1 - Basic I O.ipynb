# %%
import cv2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # First lecture - Jupyter notebook
#
# - ESC `a`: insert cell above
# - ESC `b`: insert cell below
# - ESC `m`: Markdown mode
# - ESC `c`, `x`, `v`: cut, copy and paste
# - ESC dd: delete cell
# - Shift + Enter: Run cell and open new one
# - Ctrl + Enter: Run cell in place
#
# # H1
# ## h2
# ### h3
#
# - item 1
# - item 2
# **bold**
# *italic*

# %% [markdown]
# ## Basic I/O

# %%
img = cv2.imread('./data/img/opencv-logo.png') #TAB for autocomp.

# %%
img.shape # height (nrows), width (ncols), channels
# Out:
# (555, 599, 3)

# %% [markdown]
# ### Display an image with OpenCV functions

# %%
cv2.imshow('Window name', img) 
cv2.waitKey(0) # wait forever for user to do something
cv2.destroyAllWindows()

# %% [markdown]
# ### Reading img with matplotlib

# %%
plt.imshow(img[:,:,::-1]) #BGR vs RGB

# %%
img2 = cv2.imread("./data/img/regensburg.jpg")

# %%
plt.imshow(img2[:,:,::-1`])

# %%
plt.imshow(img2[0:200,0:200,::-1])

# %%
height, width, channels = img2.shape

# %%
new_img = img2[500:700,200:800,:]

# %%
plt.imshow(new_img[:,:,::-1])

# %%
img2[500:700, 200:800,:] = 0 # Assign values to array

# %%
plt.imshow(img2[:,:,::-1])

# %%
gray = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY) # convert to gray

# %%
plt.imshow(gray, cmap="gray") # Read correct color map

# %%
cv2.imwrite("./data/img/regensburg-gray.png",gray)
# Out:
# True
